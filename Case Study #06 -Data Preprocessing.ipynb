# %% [markdown]
# # Case Study #06 -Data Preprocessing

# %% [markdown]
# ### Submitted By : Shuhaib TP

# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 1. Load the dataset into python environment

# %%
data=pd.read_csv('titanic_dataset.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### 2. Make ‘PassengerId’ as the index column

# %%
data=pd.read_csv('titanic_dataset.csv',index_col='PassengerId')
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# ### 3. Check the basic details of the dataset

# %%
data.shape
# Out:
# (891, 11)

# %% [markdown]
# data table contains 891 rows and 11 columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
data.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %% [markdown]
# column name 'cabin contains' 687 null values out of 891 ,most of the value is missing. 'Age' column missing 177 values, Embarked column missing two values and all other columns are completely filled.

# %% [markdown]
# ### 4. Fill in all the missing values present in all the columns in the dataset

# %%
#filling missing values in age column by median method
data['Age'].fillna((data['Age'].median()), inplace=True)

# %%
# filling a value of NR(means details Not Recieved) in cabin field
data['Cabin']=data['Cabin'].fillna('NR')

# %%
# filling a value of NR(means details Not Recieved) in embarked field
data['Embarked']=data['Embarked'].fillna('NR')
# Printing the data
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
# checking Null values
data.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %% [markdown]
# ### 5. Check and handle outliers in at least 3 columns in the dataset

# %% [markdown]
# #### Finding outliers in field 'Fare'

# %%
plt.boxplot(data['Fare'])
plt.title('Fare')
# Out:
# Text(0.5, 1.0, 'Fare')

# %% [markdown]
# ##### several outliers present in this data but it is ok in ths use case because VVIP cabins are also available in the ship.

# %%
# calculating 1st, 2nd and 3rd quartiles
Q1=np.percentile(data['Fare'], 25, interpolation='midpoint')
Q2=np.percentile(data['Fare'], 50, interpolation='midpoint')
Q3=np.percentile(data['Fare'], 75, interpolation='midpoint')
print ("Q1 :", Q1)
print ("Q2 :", Q2)
print ("Q3 :", Q3)
# Out:
# Q1 : 7.9104
# Q2 : 14.4542
# Q3 : 31.0

# %%
# calculating Lower and Upper limit
IQR= Q3-Q1
Low_lim= Q1-(1.5*IQR)
Up_lim= Q3+(1.5*IQR)
print("Inter Quartile Range : ",IQR)
print("Lower Limit : ",Low_lim)
print("Upper Limit : ",Up_lim)
# Out:
# Inter Quartile Range :  23.0896
# Lower Limit :  -26.724
# Upper Limit :  65.6344

# %%
outlier_list = []
for x in data['Fare']:
        if((x>Up_lim) or (x<Low_lim)):
            outlier_list.append(x)
print('Outliers = ', outlier_list)
# Out:
# Outliers =  [71.2833, 263.0, 146.5208, 82.1708, 76.7292, 80.0, 83.475, 73.5, 263.0, 77.2875, 247.5208, 73.5, 77.2875, 79.2, 66.6, 69.55, 69.55, 146.5208, 69.55, 113.275, 76.2917, 90.0, 83.475, 90.0, 79.2, 86.5, 512.3292, 79.65, 153.4625, 135.6333, 77.9583, 78.85, 91.0792, 151.55, 247.5208, 151.55, 110.8833, 108.9, 83.1583, 262.375, 164.8667, 134.5, 69.55, 135.6333, 153.4625, 133.65, 66.6, 134.5, 263.0, 75.25, 69.3, 135.6333, 82.1708, 211.5, 227.525, 73.5, 120.0, 113.275, 90.0, 120.0, 263.0, 81.8583, 89.1042, 91.0792, 90.0, 78.2667, 151.55, 86.5, 108.9, 93.5, 221.7792, 106.425, 71.0, 106.425, 110.8833, 227.525, 79.65, 110.8833, 79.65, 79.2, 78.2667, 153.4625, 77.9583, 69.3, 76.7292, 73.5, 113.275, 133.65, 73.5, 512.3292, 76.7292, 211.3375, 110.8833, 227.525, 151.55, 227.525, 211.3375, 512.3292, 78.85, 262.375, 71.0, 86.5, 120.0, 77.9583, 211.3375, 79.2, 69.55, 120.0, 93.5, 80.0, 83.1583, 69.55, 89.1042, 164.8667, 69.55, 83.1583]

# %%
outlier_list1=pd.DataFrame(outlier_list)
outlier_list1.describe()
# Out:
#                 0
# count  116.000000
# mean   128.291629
# std     84.636908
# min     66.600000
# 25%     78.189600
# 50%     90.000000
# 75%    147.778100
# max    512.329200

# %% [markdown]
# #### Here all the outliers are greater than upper limit and i am not going to remove the outliers because it is possible to have more fare for special cabins in a ship

# %% [markdown]
# #### Finding outliers in field 'Age'

# %%
data['Age'].describe()
# Out:
# count    891.000000
# mean      29.361582
# std       13.019697
# min        0.420000
# 25%       22.000000
# 50%       28.000000
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %% [markdown]
# decimal values present in age field, rounding it into integer

# %%
data['Age']=data['Age'].apply(np.ceil)
data['Age'].describe()
# Out:
# count    891.000000
# mean      29.373737
# std       13.019974
# min        1.000000
# 25%       22.000000
# 50%       28.000000
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
plt.boxplot(data['Age'])
plt.title('Age')
# Out:
# Text(0.5, 1.0, 'Age')

# %%
# calculating 1st, 2nd and 3rd quartiles
Q1=np.percentile(data['Age'], 25, interpolation='midpoint')
Q2=np.percentile(data['Age'], 50, interpolation='midpoint')
Q3=np.percentile(data['Age'], 75, interpolation='midpoint')
print ("Q1 :", Q1)
print ("Q2 :", Q2)
print ("Q3 :", Q3)
# Out:
# Q1 : 22.0
# Q2 : 28.0
# Q3 : 35.0

# %%
# calculating Lower and Upper limit
IQR= Q3-Q1
Low_lim= Q1-(1.5*IQR)
Up_lim= Q3+(1.5*IQR)
print("Inter Quartile Range : ",IQR)
print("Lower Limit : ",Low_lim)
print("Upper Limit : ",Up_lim)
# Out:
# Inter Quartile Range :  13.0
# Lower Limit :  2.5
# Upper Limit :  54.5

# %%
outlier_list = []
for x in data['Age']:
        if((x>Up_lim) or (x<Low_lim)):
            outlier_list.append(x)
print('Outliers = ', outlier_list)
# Out:
# Outliers =  [2.0, 58.0, 55.0, 2.0, 66.0, 65.0, 1.0, 59.0, 71.0, 71.0, 2.0, 56.0, 1.0, 61.0, 1.0, 56.0, 1.0, 58.0, 2.0, 59.0, 62.0, 58.0, 63.0, 65.0, 2.0, 1.0, 61.0, 2.0, 60.0, 1.0, 1.0, 64.0, 65.0, 56.0, 1.0, 2.0, 63.0, 58.0, 55.0, 71.0, 2.0, 64.0, 62.0, 62.0, 60.0, 61.0, 57.0, 80.0, 2.0, 1.0, 56.0, 58.0, 70.0, 60.0, 60.0, 70.0, 1.0, 57.0, 1.0, 1.0, 2.0, 1.0, 62.0, 1.0, 74.0, 56.0]

# %%
outlier_list1=pd.DataFrame(outlier_list)
outlier_list1.describe()
# Out:
#                0
# count  66.000000
# mean   39.984848
# std    29.727735
# min     1.000000
# 25%     2.000000
# 50%    57.500000
# 75%    62.000000
# max    80.000000

# %% [markdown]
# #### The actual minimum value of age is .42 and it is rounded to 1.
# #### Also the upper limit is 54.5 , maximum value is 80 and it is possible to have age greater than 54.5, hence not removing any rows

# %% [markdown]
# #### Finding outliers in field 'Pclass'

# %%
plt.boxplot(data['Pclass'])
plt.title('Pclass')
# Out:
# Text(0.5, 1.0, 'Pclass')

# %%
# calculating 1st, 2nd and 3rd quartiles
Q1=np.percentile(data['Pclass'], 25, interpolation='midpoint')
Q2=np.percentile(data['Pclass'], 50, interpolation='midpoint')
Q3=np.percentile(data['Pclass'], 75, interpolation='midpoint')
print ("Q1 :", Q1)
print ("Q2 :", Q2)
print ("Q3 :", Q3)
# calculating Lower and Upper limit
IQR= Q3-Q1
Low_lim= Q1-(1.5*IQR)
Up_lim= Q3+(1.5*IQR)
print("Inter Quartile Range : ",IQR)
print("Lower Limit : ",Low_lim)
print("Upper Limit : ",Up_lim)
# Out:
# Q1 : 2.0
# Q2 : 3.0
# Q3 : 3.0
# Inter Quartile Range :  1.0
# Lower Limit :  0.5
# Upper Limit :  4.5

# %%
outlier_list = []
for x in data['Pclass']:
        if((x>Up_lim) or (x<Low_lim)):
            outlier_list.append(x)
print('Outliers = ', outlier_list)
# Out:
# Outliers =  []

# %% [markdown]
# No outliers Present in this field

# %% [markdown]
# ### 6. Do min max scaling on the feature set (Take ‘Survived’ as target)

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#Dropping some field for creating dummy
df=data.drop(['Name','Ticket','Cabin'], axis=1)
df=pd.get_dummies(df)
df
# Out:
#              Survived  Pclass   Age  SibSp  Parch     Fare  Sex_female  \
# PassengerId
# 1                   0       3  22.0      1      0   7.2500           0
# 2                   1       1  38.0      1      0  71.2833           1
# 3                   1       3  26.0      0      0   7.9250           1
# 4                   1       1  35.0      1      0  53.1000           1
# 5                   0       3  35.0      0      0   8.0500           0
# ...               ...     ...   ...    ...    ...      ...         ...
# 887                 0       2  27.0      0      0  13.0000           0
# 888                 1       1  19.0      0      0  30.0000           1
# 889                 0       3  28.0      1      2  23.4500           1
# 890                 1       1  26.0      0      0  30.0000           0
# 891                 0       3  32.0      0      0   7.7500           0
#
#              Sex_male  Embarked_C  Embarked_NR  Embarked_Q  Embarked_S
# PassengerId
# ...

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.373737    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.019974    1.102743    0.806057   49.693429
# min      0.000000    1.000000    1.000000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
#
#        Sex_female    Sex_male  Embarked_C  Embarked_NR  Embarked_Q  Embarked_S
# count  891.000000  891.000000  891.000000   891.000000  891.000000  891.000000
# mean     0.352413    0.647587    0.188552     0.002245    0.086420    0.722783
# ...

# %%
y=df['Survived']
x=df.drop('Survived', axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=42, test_size=0.2)
lr= linear_model.LinearRegression()
model=lr.fit(x_train, y_train)
predictions= model.predict(x_test)
print("MSE is : ", mean_squared_error(y_test, predictions))
print('R Squared Value is : ', r2_score(y_test,predictions))
# Out:
# MSE is :  0.13502031019064792
# R Squared Value is :  0.4432193360593887

# %%
min_max= preprocessing.MinMaxScaler(feature_range=(0,1))
df['Survived']=min_max.fit_transform(df[['Survived']])
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.373737    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.019974    1.102743    0.806057   49.693429
# min      0.000000    1.000000    1.000000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
#
#        Sex_female    Sex_male  Embarked_C  Embarked_NR  Embarked_Q  Embarked_S
# count  891.000000  891.000000  891.000000   891.000000  891.000000  891.000000
# mean     0.352413    0.647587    0.188552     0.002245    0.086420    0.722783
# ...

# %% [markdown]
# There is no effect in sclaing by taking survived as target
# Let's try with whole field

# %%
x=min_max.fit_transform(x)

# %%
x=pd.DataFrame(x)
x.describe()
# Out:
#                0           1           2           3           4           5   \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.654321    0.359161    0.065376    0.063599    0.062858    0.352413
# std      0.418036    0.164810    0.137843    0.134343    0.096995    0.477990
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.500000    0.265823    0.000000    0.000000    0.015440    0.000000
# 50%      1.000000    0.341772    0.000000    0.000000    0.028213    0.000000
# 75%      1.000000    0.430380    0.125000    0.000000    0.060508    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#                6           7           8           9           10
# count  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.647587    0.188552    0.002245    0.086420    0.722783
# std      0.477990    0.391372    0.047351    0.281141    0.447876
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=42, test_size=0.2)
lr= linear_model.LinearRegression()
model=lr.fit(x_train, y_train)
predictions= model.predict(x_test)
print("MSE is : ", mean_squared_error(y_test, predictions))
print('R Squared Value is : ', r2_score(y_test,predictions))
# Out:
# MSE is :  0.1350203101906479
# R Squared Value is :  0.4432193360593887

# %% [markdown]
# ### The MSE and R Squared value is same before and after scaling, hence there is no effect on data by min max scaling
